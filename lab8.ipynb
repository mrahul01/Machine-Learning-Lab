# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

df =pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df,hue='Species',diag_kind='hist',palette='dark')
plt.show()

# %%
X = df.drop(columns='Species')
y = df['Species']

# %% [markdown]
# ## Logistic Regreesion

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=40)

LR_clf = LogisticRegression(solver='lbfgs',max_iter=1000)
LR_clf.fit(X_train,y_train)

LR_pred = LR_clf.predict(X_test)

LR_acc = accuracy_score(y_test,LR_pred)
LR_repo = classification_report(y_test,LR_pred)
print(f"The Accuracy of Logistic Regression is : {LR_acc}")
print(f"\nThe Classification report of Logistic Regression is :\n {LR_repo}")
# Out:
# The Accuracy of Logistic Regression is : 1.0
#
# The Classification report of Logistic Regression is :
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      1.00      1.00        14
#  Iris-virginica       1.00      1.00      1.00        15
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
SVM_clf = SVC()
SVM_clf.fit(X_train,y_train)


SVM_pred = SVM_clf.predict(X_test)

SVM_acc = accuracy_score(y_test,SVM_pred)
SVM_repo = classification_report(y_test,SVM_pred)
print(f"The Accuracy of Support Vector Machine is : {SVM_acc}")
print(f"\nThe Classification report of Support Vector Machine is :\n {SVM_repo}")
# Out:
# The Accuracy of Support Vector Machine is : 1.0
#
# The Classification report of Support Vector Machine is :
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      1.00      1.00        14
#  Iris-virginica       1.00      1.00      1.00        15
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
DT_clf = DecisionTreeClassifier()
DT_clf.fit(X_train,y_train)


DT_pred = DT_clf.predict(X_test)

DT_acc = accuracy_score(y_test,DT_pred)
DT_repo = classification_report(y_test,DT_pred)
print(f"The Accuracy of Decision Tree is : {DT_acc}")
print(f"\nThe Classification report of Decision Tree is :\n {DT_repo}")
# Out:
# The Accuracy of Decision Tree is : 1.0
#
# The Classification report of Decision Tree is :
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      1.00      1.00        14
#  Iris-virginica       1.00      1.00      1.00        15
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
NB_clf = GaussianNB()
NB_clf.fit(X_train,y_train)


NB_pred = NB_clf.predict(X_test)

NB_acc = accuracy_score(y_test,NB_pred)
NB_repo = classification_report(y_test,NB_pred)
print(f"The Accuracy of Naive Bayes is : {NB_acc}")
print(f"\nThe Classification report of Naive Bayes is :\n {NB_repo}")
# Out:
# The Accuracy of Naive Bayes is : 1.0
#
# The Classification report of Naive Bayes is :
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      1.00      1.00        14
#  Iris-virginica       1.00      1.00      1.00        15
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_clf = KNeighborsClassifier(n_neighbors=2)
KNN_clf.fit(X_train,y_train)


KNN_pred = KNN_clf.predict(X_test)

KNN_acc = accuracy_score(y_test,KNN_pred)
KNN_repo = classification_report(y_test,KNN_pred)
print(f"The Accuracy of KNN is : {KNN_acc}")
print(f"\nThe Classification report of KNN is :\n {KNN_repo}")
# Out:
# The Accuracy of KNN is : 1.0
#
# The Classification report of KNN is :
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       1.00      1.00      1.00        14
#  Iris-virginica       1.00      1.00      1.00        15
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
